# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

df = pd.read_csv("Civil_Engineering_Regression_Dataset.csv")
print(df.columns)  

X = df[['Building_Height']]
y = df['Construction_Cost']

model = LinearRegression()
model.fit(X, y)

slope = model.coef_[0]
intercept = model.intercept_
print(f"Regression Equation: Construction Cost = {intercept:.2f} + {slope:.2f} * Building Height")

print(f"Interpretation: For each additional unit increase in Building Height, Construction Cost changes by {slope:.2f} units.")

y_pred = model.predict(X)

mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R²): {r2:.2f}")

plt.scatter(X, y, color='blue', label='Actual data')
plt.plot(X, y_pred, color='red', linewidth=2, label='Regression Line')
plt.xlabel("Building Height")
plt.ylabel("Construction Cost")
plt.title("Simple Linear Regression: Building Height vs. Construction Cost")
plt.legend()
plt.show()
# Out:
# Index(['Project_ID', 'Building_Height', 'Material_Quality_Index', 'Labor_Cost',
#        'Concrete_Strength', 'Foundation_Depth', 'Weather_Index',
#        'Construction_Cost'],
#       dtype='object')
# Regression Equation: Construction Cost = 994.03 + 50.21 * Building Height
# Interpretation: For each additional unit increase in Building Height, Construction Cost changes by 50.21 units.
# Mean Squared Error (MSE): 41323.45
# R-squared (R²): 0.92
