# %% [markdown]
# ### Key Takeaways:
# 1. The multiple linear regression model provided a higher R-squared value than the simple regression model, indicating better predictive performance.
# 2. Among the independent variables, [Variable with highest impact] had the most significant effect on Construction Cost.
# 3. The Adjusted R-squared value helped confirm the model's effectiveness while accounting for the number of predictors.
# 4. VIF analysis revealed potential multicollinearity, suggesting some independent variables may be correlated.
#
# Applications for Construction Companies:
# - Regression models allow for more accurate cost estimation, aiding in budget planning.
# - Companies can identify key cost drivers and optimize resource allocation.
# - Predictive models assist in risk assessment by forecasting potential budget overruns.
#
# Limitations Encountered:
# - Possible multicollinearity among independent variables.
# - The dataset may lack important variables such as location, project duration, or labor efficiency.
# - External factors (e.g., economic fluctuations, material price changes) are not considered.
#
# Potential Model Improvements:
# - Including additional variables like inflation rates, project complexity, and contractor experience.
# - Collecting a larger dataset for better generalization.
# - Using advanced regression techniques like ridge regression to mitigate multicollinearity.
#
# Role of Regression Analysis in Civil Engineering:
# - Enables data-driven decision-making for cost-effective project planning.
# - Helps engineers optimize material selection and labor distribution.
# - Improves financial forecasting, reducing unexpected cost overruns.
#
# Conclusion:
# Data science plays a crucial role in construction cost optimization by leveraging regression models for accurate cost predictions. By continuously improving models with better data and techniques, construction firms can enhance project efficiency, reduce financial risks, and ensure sustainable development.

# %%
import pandas as pd
df = pd.read_csv("Civil_Engineering_Regression_Dataset.csv")
df
# Out:
#     Project_ID  Building_Height  Material_Quality_Index  Labor_Cost  \
# 0            1        21.854305                       9   70.213332
# 1            2        47.782144                       9  142.413614
# 2            3        37.939727                       3  110.539985
# 3            4        31.939632                       6  250.784939
# 4            5        12.020839                       7  167.575159
# ..         ...              ...                     ...         ...
# 95          96        27.220802                       6   97.727758
# 96          97        28.522977                       4  117.118714
# 97          98        24.239346                       8  171.319969
# 98          99         6.143861                       9  143.171717
# 99         100         9.855114                       6  148.672867
#
#     Concrete_Strength  Foundation_Depth  Weather_Index  Construction_Cost
# 0           45.326394          8.804790              4        2400.287931
# ...
